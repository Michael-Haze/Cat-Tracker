# %%
import pandas as pd

# %%
df = pd.read_excel("CatTracker_Mar 2023 (2).xlsm")

# %%
#Set column headers and drop row
df.columns = df.iloc[0]
df = df.drop(0)

# %%
df = df.drop(67691) #row with one blank

# %%
df = df.dropna(how='all', axis=0) #drop na rows
df = df.dropna(how='all', axis=1) #drop na columns
#df.columns = df.iloc[0] #set column names

# %%
df.columns
# Out:
# Index(['      month', '      day', '      year', 'Disposition', '      room',
#        '     adoptable now?', '    listed on PF?', 'Cat name', 'D_H',
#        'Description', '      sex', 'DOB', 'AGE', '      age group',
#        '     -month', '     -day', '     -year', 'Vet', 'status',
#        '      FVRCP 1', '      FVRCP 2', '      FVRCP 3', '      FVRCP 4',
#        '      FVRCP 5', '      rabies', '      type',
#        '      date\n      (most recent)', 'F',
#        '      date\n      (most recent)2', 'Column2', 'Intake Information',
#        'Was cat trapped?'],
#       dtype='object', name=0)

# %%
df[['Cat name', 'AGE', 'DOB', '      month', '      day', '      year', 'Description', '      room']]
# Out:
# 0        Cat name       AGE                  DOB       month       day  \
# 1          Adonis  15.2 yrs  2008-09-01 00:00:00           1         6
# 2          Benson       NaN                  NaN          12        10
# 3            Cece  24.4 yrs  1999-06-16 00:00:00           6        16
# 4            Coco  24.4 yrs  1999-06-16 00:00:00           6        16
# 5     Koko (Kiki)  19.2 yrs  2004-08-01 00:00:00           7        25
# ...           ...       ...                  ...         ...       ...
# 3259        Woody   9.7 yrs  2014-02-01 00:00:00           1        28
# 3276     Terra #1  14.8 yrs  2009-01-01 00:00:00           1        12
# 3280          V-6  17.3 yrs  2006-07-01 00:00:00           6         7
# 3281   Heidi Girl  13.8 yrs  2010-01-01 00:00:00           2        23
# 3282     Princess       NaN                  NaN           7       NaN
#
# 0          year                  Description       room
# 1          2009    Silver/Blk. Classic Tabby          6
# ...
